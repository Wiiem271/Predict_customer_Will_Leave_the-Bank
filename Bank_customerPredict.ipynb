# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
### Data Preprocessing

# %%
dataset = pd.read_csv('BankCustomers.csv')
dataset
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
x = dataset.iloc[:,3:13]
y = dataset.iloc[:,13]

# %%
# convert categorical feature into dummy variables
states=pd.get_dummies(x['Geography'],drop_first=True)
gender=pd.get_dummies(x['Gender'],drop_first=True)

# %%
#drop the columns as it is no longer required
x=x.drop(['Geography','Gender'],axis=1)

# %%
#concatenate the remaining dummies columns
x=pd.concat([x,states,gender],axis=1)

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
# Part 2 - Now let's make the ANN!

# %%
# Importing the Keras libraries and packages
import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
# Initialising the ANN
classifier = Sequential()

# %%
# Adding the input layer and the first hidden layer
classifier.add(Dense(activation="relu", input_dim=11, units=6, kernel_initializer="uniform"))

# %%
# Adding the second hidden layer
classifier.add(Dense(activation="relu", units=6, kernel_initializer="uniform"))

# %%
# Adding the output layer
classifier.add(Dense(activation="sigmoid", units=1, kernel_initializer="uniform"))

# %%
# Compiling the ANN
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
# Fitting the ANN to the Training set
classifier.fit(X_train, y_train, batch_size = 10, epochs= 100)
# Out:
# Epoch 1/100
# 800/800 [==============================] - 3s 3ms/step - loss: 0.4972 - accuracy: 0.7950
# Epoch 2/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4302 - accuracy: 0.7960
# Epoch 3/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4250 - accuracy: 0.7960
# Epoch 4/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4205 - accuracy: 0.8004
# Epoch 5/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4173 - accuracy: 0.8229
# Epoch 6/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4153 - accuracy: 0.8278
# Epoch 7/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4138 - accuracy: 0.8280
# Epoch 8/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4125 - accuracy: 0.8295
# Epoch 9/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4113 - accuracy: 0.8296
# Epoch 10/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4105 - accuracy: 0.8322
# Epoch 11/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4095 - accuracy: 0.8321
# Epoch 12/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4087 - accuracy: 0.8331
# Epoch 13/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4078 - accuracy: 0.8330
# Epoch 14/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4075 - accuracy: 0.8322
# Epoch 15/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4068 - accuracy: 0.8340
# Epoch 16/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4060 - accuracy: 0.8347
# Epoch 17/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4057 - accuracy: 0.8342
# Epoch 18/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4055 - accuracy: 0.8338
# Epoch 19/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4054 - accuracy: 0.8338
# Epoch 20/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4044 - accuracy: 0.8339
# Epoch 21/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4036 - accuracy: 0.8336
# Epoch 22/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4026 - accuracy: 0.8345
# Epoch 23/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4020 - accuracy: 0.8342
# Epoch 24/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4013 - accuracy: 0.8353
# Epoch 25/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4008 - accuracy: 0.8349
# Epoch 26/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4001 - accuracy: 0.8355
# Epoch 27/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3993 - accuracy: 0.8341
# Epoch 28/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3992 - accuracy: 0.8339
# Epoch 29/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3984 - accuracy: 0.8350
# Epoch 30/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3983 - accuracy: 0.8336
# Epoch 31/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3978 - accuracy: 0.8347
# Epoch 32/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3975 - accuracy: 0.8351
# Epoch 33/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3971 - accuracy: 0.8341
# Epoch 34/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3967 - accuracy: 0.8355
# Epoch 35/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3969 - accuracy: 0.8355
# Epoch 36/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3964 - accuracy: 0.8349
# Epoch 37/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3965 - accuracy: 0.8347
# Epoch 38/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3959 - accuracy: 0.8374
# Epoch 39/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3959 - accuracy: 0.8364
# Epoch 40/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3957 - accuracy: 0.8360
# Epoch 41/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3958 - accuracy: 0.8341
# Epoch 42/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3953 - accuracy: 0.8357
# Epoch 43/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3957 - accuracy: 0.8354
# Epoch 44/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3950 - accuracy: 0.8359
# Epoch 45/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3957 - accuracy: 0.8351
# Epoch 46/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3953 - accuracy: 0.8356
# Epoch 47/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3949 - accuracy: 0.8345
# Epoch 48/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3945 - accuracy: 0.8354
# Epoch 49/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3946 - accuracy: 0.8349
# Epoch 50/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3950 - accuracy: 0.8350
# Epoch 51/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3949 - accuracy: 0.8357
# Epoch 52/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3947 - accuracy: 0.8344
# Epoch 53/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3944 - accuracy: 0.8366
# Epoch 54/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3950 - accuracy: 0.8350
# Epoch 55/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3944 - accuracy: 0.8367
# Epoch 56/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3941 - accuracy: 0.8353
# Epoch 57/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3943 - accuracy: 0.8360
# Epoch 58/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3944 - accuracy: 0.8353
# Epoch 59/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3944 - accuracy: 0.8353
# Epoch 60/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3943 - accuracy: 0.8360
# Epoch 61/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3947 - accuracy: 0.8364
# Epoch 62/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3942 - accuracy: 0.8355
# Epoch 63/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3947 - accuracy: 0.8360
# Epoch 64/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3940 - accuracy: 0.8376
# Epoch 65/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3943 - accuracy: 0.8359
# Epoch 66/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3944 - accuracy: 0.8354
# Epoch 67/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3938 - accuracy: 0.8357
# Epoch 68/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3940 - accuracy: 0.8347
# Epoch 69/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3941 - accuracy: 0.8372
# Epoch 70/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3938 - accuracy: 0.8364
# Epoch 71/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3939 - accuracy: 0.8342
# Epoch 72/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3937 - accuracy: 0.8345
# Epoch 73/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3937 - accuracy: 0.8344
# Epoch 74/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3942 - accuracy: 0.8370
# Epoch 75/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3940 - accuracy: 0.8359
# Epoch 76/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3938 - accuracy: 0.8365
# Epoch 77/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3937 - accuracy: 0.8372
# Epoch 78/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3932 - accuracy: 0.8369
# Epoch 79/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3942 - accuracy: 0.8353
# Epoch 80/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3937 - accuracy: 0.8356
# Epoch 81/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3937 - accuracy: 0.8351
# Epoch 82/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3936 - accuracy: 0.8381
# Epoch 83/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3932 - accuracy: 0.8382
# Epoch 84/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3936 - accuracy: 0.8365
# Epoch 85/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3931 - accuracy: 0.8366
# Epoch 86/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3936 - accuracy: 0.8346
# Epoch 87/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3935 - accuracy: 0.8366
# Epoch 88/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3933 - accuracy: 0.8354
# Epoch 89/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3933 - accuracy: 0.8355
# Epoch 90/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3935 - accuracy: 0.8371
# Epoch 91/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3937 - accuracy: 0.8367
# Epoch 92/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3938 - accuracy: 0.8367
# Epoch 93/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3934 - accuracy: 0.8364
# Epoch 94/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3936 - accuracy: 0.8356
# Epoch 95/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3931 - accuracy: 0.8351
# Epoch 96/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3935 - accuracy: 0.8357
# Epoch 97/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3927 - accuracy: 0.8380
# Epoch 98/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3931 - accuracy: 0.8372
# Epoch 99/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3926 - accuracy: 0.8363
# Epoch 100/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3937 - accuracy: 0.8364

# %%
# Part 3 - Making the predictions and evaluating the model

# %%
# Predicting the Test set results
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)
# Out:
# 63/63 [==============================] - 0s 2ms/step

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix,accuracy_score
cm = confusion_matrix(y_test, y_pred)
accuracy=accuracy_score(y_test,y_pred)

# %%
accuracy
# Out:
# 0.843
